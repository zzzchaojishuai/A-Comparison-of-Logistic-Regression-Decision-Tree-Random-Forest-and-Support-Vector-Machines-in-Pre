# %% [markdown]
# <a href="https://colab.research.google.com/github/zzzchaojishuai/A-Comparison-of-Logistic-Regression-Decision-Tree-Random-Forest-and-Support-Vector-Machines-in-Pre/blob/master/%E2%80%9Cdata_collection_and_cleaning_ipynb_hexv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://storage.googleapis.com/public-data-data_viz-2/fashionweeks-2019-instagram-geospatial-clean.csv
# Out:
# --2020-05-13 11:51:33--  https://storage.googleapis.com/public-data-data_viz-2/fashionweeks-2019-instagram-geospatial-clean.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.11.128, 2607:f8b0:400c:c02::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.11.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3254549 (3.1M) [text/csv]
# Saving to: ‘fashionweeks-2019-instagram-geospatial-clean.csv’
#
# fashionweeks-2019-i 100%[===================>]   3.10M  --.-KB/s    in 0.01s
#
# 2020-05-13 11:51:33 (219 MB/s) - ‘fashionweeks-2019-instagram-geospatial-clean.csv’ saved [3254549/3254549]

# %%
import pandas as pd

fashion_weeks_19 = pd.read_csv('fashionweeks-2019-instagram-geospatial-clean.csv')
print(fashion_weeks_19.shape)
# Out:
# (22752, 16)

# %%
#show the fashion week 2019 dataframe
fashion_weeks_19.head()
# Out:
#          date                 time  ...   latitude  longitude
# 0  2019-09-16  2019-09-16 13:39:38  ...  40.702285 -73.995583
# 1  2019-01-06  2019-01-06 18:12:42  ...  40.749904 -73.991040
# 2  2019-09-05  2019-09-05 15:40:45  ...  40.720873 -74.006004
# 3  2019-12-31  2019-12-31 12:56:12  ...  40.720873 -74.006004
# 4  2019-12-31  2019-12-31 03:37:39  ...  40.720839 -74.005973
#
# [5 rows x 16 columns]

# %%
#show the number of posts per city
fashion_weeks_19.filename.value_counts()
# Out:
# nyfw2019    18918
# pfw2019      2052
# lfw2019      1782
# Name: filename, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#airbnb data
# !wget https://storage.googleapis.com/public-data-data_viz-2/london-listings-master-2019.csv
# !wget https://storage.googleapis.com/public-data-data_viz-2/newyork-listings-master-2019.csv
# !wget https://storage.googleapis.com/public-data-data_viz-2/paris-listings-master-2019.csv
# Out:
# --2020-05-13 11:51:35--  https://storage.googleapis.com/public-data-data_viz-2/london-listings-master-2019.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.217.128, 2607:f8b0:400c:c12::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.217.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114143909 (109M) [text/csv]
# Saving to: ‘london-listings-master-2019.csv’
#
# london-listings-mas 100%[===================>] 108.86M   111MB/s    in 1.0s
#
# 2020-05-13 11:51:36 (111 MB/s) - ‘london-listings-master-2019.csv’ saved [114143909/114143909]
#
# --2020-05-13 11:51:37--  https://storage.googleapis.com/public-data-data_viz-2/newyork-listings-master-2019.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.216.128, 2607:f8b0:400c:c0f::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.216.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79185159 (76M) [text/csv]
# Saving to: ‘newyork-listings-master-2019.csv’
#
# newyork-listings-ma 100%[===================>]  75.52M   134MB/s    in 0.6s
#
# 2020-05-13 11:51:38 (134 MB/s) - ‘newyork-listings-master-2019.csv’ saved [79185159/79185159]
#
# --2020-05-13 11:51:39--  https://storage.googleapis.com/public-data-data_viz-2/paris-listings-master-2019.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.213.128, 2607:f8b0:400c:c12::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.213.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102189583 (97M) [text/csv]
# Saving to: ‘paris-listings-master-2019.csv’
#
# paris-listings-mast 100%[===================>]  97.46M   163MB/s    in 0.6s
#
# 2020-05-13 11:51:40 (163 MB/s) - ‘paris-listings-master-2019.csv’ saved [102189583/102189583]

# %%
london_airbnb = pd.read_csv('london-listings-master-2019.csv')
newyork_airbnb = pd.read_csv('newyork-listings-master-2019.csv')
paris_airbnb = pd.read_csv('paris-listings-master-2019.csv')

# %%
print(london_airbnb.shape, newyork_airbnb.shape, paris_airbnb.shape)
# Out:
# (840212, 16) (592519, 16) (744575, 16)

# %%
london_airbnb.isna().sum()
# Out:
# Unnamed: 0                0
# id                        0
# host_id                   0
# last_scraped              0
# zipcode               19541
# latitude                 10
# longitude                10
# neighbourhood            16
# property_type            10
# room_type                10
# price                    10
# number_of_reviews        10
# last_review          208100
# year_scraped              0
# month_scraped             0
# day_scraped               0
# dtype: int64

# %%
london_airbnb.dropna()
# Out:
#         Unnamed: 0        id  ...  month_scraped day_scraped
# 0                0  29588041  ...              7          12
# 1                1   2456256  ...              7          12
# 2                2  28972251  ...              7          12
# 3                3  14074467  ...              7          12
# 4                4  28973074  ...              7          12
# ...            ...       ...  ...            ...         ...
# 840179     1872147  39377815  ...             11           6
# 840180     1872148  39284619  ...             11           6
# 840182     1872150  39740287  ...             11           6
# 840192     1872160  22701498  ...             11           6
# 840196     1872164  38398365  ...             11           6
#
# [617431 rows x 16 columns]

# %%
london_airbnb.describe()
# Out:
#          Unnamed: 0            id  ...  month_scraped    day_scraped
# count  8.402120e+05  8.402120e+05  ...  840212.000000  840212.000000
# mean   9.362641e+05  2.158722e+07  ...       7.574217       9.865426
# std    7.226262e+05  1.056149e+07  ...       2.848704       3.277162
# min    0.000000e+00  1.155100e+04  ...       3.000000       5.000000
# 25%    2.100528e+05  1.367955e+07  ...       5.000000       7.000000
# 50%    1.364838e+06  2.209394e+07  ...       8.000000      10.000000
# 75%    1.662126e+06  3.038785e+07  ...      10.000000      11.000000
# max    1.872179e+06  4.067901e+07  ...      12.000000      30.000000
#
# [8 rows x 9 columns]

# %%
london_airbnb['price_float'] = london_airbnb['price'].str.replace(',', '').astype(float)

# %%
london_airbnb.describe()
# Out:
#          Unnamed: 0            id  ...    day_scraped    price_float
# count  8.402120e+05  8.402120e+05  ...  840212.000000  840202.000000
# mean   9.362641e+05  2.158722e+07  ...       9.865426     121.185726
# std    7.226262e+05  1.056149e+07  ...       3.277162     252.993055
# min    0.000000e+00  1.155100e+04  ...       5.000000       0.000000
# 25%    2.100528e+05  1.367955e+07  ...       7.000000      45.000000
# 50%    1.364838e+06  2.209394e+07  ...      10.000000      80.000000
# 75%    1.662126e+06  3.038785e+07  ...      11.000000     137.000000
# max    1.872179e+06  4.067901e+07  ...      30.000000   20000.000000
#
# [8 rows x 10 columns]

# %%
mean = london_airbnb['price_float'].mean()
mean
# Out:
# 121.18572557551636

# %%
std = london_airbnb['price_float'].std()
std
# Out:
# 252.99305545327857

# %%
london_airbnb.price_float
# Out:
# 0          30.0
# 1          23.0
# 2          70.0
# 3          38.0
# 4          50.0
#           ...
# 840207     70.0
# 840208     69.0
# 840209     90.0
# 840210     30.0
# 840211    187.0
# Name: price_float, Length: 840212, dtype: float64

# %%
london_airbnb_1 = london_airbnb[london_airbnb['price_float']<=880]
london_airbnb_1
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0  29588041  ...           12        30.0
# 1                1   2456256  ...           12        23.0
# 2                2  28972251  ...           12        70.0
# 3                3  14074467  ...           12        38.0
# 4                4  28973074  ...           12        50.0
# ...            ...       ...  ...          ...         ...
# 840207     1872175  39868875  ...            6        70.0
# 840208     1872176  39869123  ...            6        69.0
# 840209     1872177  39869214  ...            6        90.0
# 840210     1872178  39869249  ...            6        30.0
# 840211     1872179  39869282  ...            6       187.0
#
# [834019 rows x 17 columns]

# %%
london_airbnb_1.dropna()
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0  29588041  ...           12        30.0
# 1                1   2456256  ...           12        23.0
# 2                2  28972251  ...           12        70.0
# 3                3  14074467  ...           12        38.0
# 4                4  28973074  ...           12        50.0
# ...            ...       ...  ...          ...         ...
# 840179     1872147  39377815  ...            6        50.0
# 840180     1872148  39284619  ...            6       260.0
# 840182     1872150  39740287  ...            6       150.0
# 840192     1872160  22701498  ...            6       115.0
# 840196     1872164  38398365  ...            6       117.0
#
# [615079 rows x 17 columns]

# %%
london_airbnb_1['last_review'] = pd.to_datetime(london_airbnb_1['last_review'])

# %%
london_airbnb_1.sort_values('last_review', inplace=True)

# %%
london_airbnb_1.head()
# Out:
#         Unnamed: 0     id  host_id  ... month_scraped day_scraped  price_float
# 372118      372118  41870   182993  ...             3           8         35.0
# 231730      231730  41870   182993  ...             5           6         35.0
# 294475      294475  41870   182993  ...             4          11         35.0
# 405469     1350202  41870   182993  ...            12          11         35.0
# 94393        94393  41870   182993  ...             6           7         35.0
#
# [5 rows x 17 columns]

# %%
london_airbnb_1.shape
# Out:
# (834019, 17)

# %%
london_airbnb_1['date'] = london_airbnb_1['last_review']

# %%
london_airbnb_1.set_index("date", inplace=True)

# %%
london_airbnb_2019 = london_airbnb_1[london_airbnb_1['last_review']>=pd.datetime(2019,1,1)]
london_airbnb_2019
# Out:
#             Unnamed: 0        id  ...  day_scraped price_float
# date                              ...
# 2019-01-01      191065   3218197  ...            6       144.0
# 2019-01-01      378303   4289128  ...            8        75.0
# 2019-01-01      345182  30693963  ...            8        80.0
# 2019-01-01      345108  30692314  ...            8       100.0
# 2019-01-01      341045  21167345  ...            8        60.0
# ...                ...       ...  ...          ...         ...
# 2019-12-11     1401873  28450140  ...           11        85.0
# 2019-12-11     1430942  39527801  ...           11       100.0
# 2019-12-11     1359021   6872783  ...           11       100.0
# 2019-12-11     1415896  34841135  ...           11        30.0
# 2019-12-11     1430377  39385120  ...           11        80.0
#
# [410945 rows x 17 columns]

# %%
london_airbnb_2019.dropna()
# Out:
#             Unnamed: 0        id  ...  day_scraped price_float
# date                              ...
# 2019-01-01      191065   3218197  ...            6       144.0
# 2019-01-01      378303   4289128  ...            8        75.0
# 2019-01-01      345182  30693963  ...            8        80.0
# 2019-01-01      345108  30692314  ...            8       100.0
# 2019-01-01      341045  21167345  ...            8        60.0
# ...                ...       ...  ...          ...         ...
# 2019-12-11     1401873  28450140  ...           11        85.0
# 2019-12-11     1430942  39527801  ...           11       100.0
# 2019-12-11     1359021   6872783  ...           11       100.0
# 2019-12-11     1415896  34841135  ...           11        30.0
# 2019-12-11     1430377  39385120  ...           11        80.0
#
# [401803 rows x 17 columns]

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=london_airbnb_2019, color='tab:red')

# %%
london_airbnb_2019_day= london_airbnb_2019.resample('D').mean()
london_airbnb_2019_day = london_airbnb_2019_day.round(3)
london_airbnb_2019_day
# Out:
#              Unnamed: 0            id  ...  day_scraped  price_float
# date                                   ...
# 2019-01-01   606189.818  2.108613e+07  ...        9.129      113.867
# 2019-01-02   606677.986  2.021317e+07  ...        9.077      121.921
# 2019-01-03   625997.801  1.982571e+07  ...        9.133      124.692
# 2019-01-04   612052.311  1.866591e+07  ...        9.130      133.680
# 2019-01-05   586243.958  1.889251e+07  ...        9.080      133.648
# ...                 ...           ...  ...          ...          ...
# 2019-12-07  1401361.366  2.732445e+07  ...       10.396       89.540
# 2019-12-08  1401520.167  2.737199e+07  ...       10.429       93.315
# 2019-12-09  1401380.710  2.727290e+07  ...       10.501       91.292
# 2019-12-10  1402149.970  2.735700e+07  ...       10.628       82.020
# 2019-12-11  1405955.000  2.857790e+07  ...       11.000       94.875
#
# [345 rows x 10 columns]

# %%
london_airbnb_2019_day.dropna()
# Out:
#              Unnamed: 0            id  ...  day_scraped  price_float
# date                                   ...
# 2019-01-01   606189.818  2.108613e+07  ...        9.129      113.867
# 2019-01-02   606677.986  2.021317e+07  ...        9.077      121.921
# 2019-01-03   625997.801  1.982571e+07  ...        9.133      124.692
# 2019-01-04   612052.311  1.866591e+07  ...        9.130      133.680
# 2019-01-05   586243.958  1.889251e+07  ...        9.080      133.648
# ...                 ...           ...  ...          ...          ...
# 2019-12-07  1401361.366  2.732445e+07  ...       10.396       89.540
# 2019-12-08  1401520.167  2.737199e+07  ...       10.429       93.315
# 2019-12-09  1401380.710  2.727290e+07  ...       10.501       91.292
# 2019-12-10  1402149.970  2.735700e+07  ...       10.628       82.020
# 2019-12-11  1405955.000  2.857790e+07  ...       11.000       94.875
#
# [345 rows x 10 columns]

# %%
london_airbnb_2019_day['ma10'] = london_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
london_airbnb_2019_day['ma20'] = london_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)

# %%
london_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
newyork_airbnb['price_float'] = newyork_airbnb['price'].str.replace(',', '').astype(float)

# %%
mean = newyork_airbnb['price_float'].mean()
std = newyork_airbnb['price_float'].std()
mean
# Out:
# 152.92387782105897

# %%
s = mean+3*std
s
# Out:
# 919.8566989844694

# %%
newyork_airbnb_1 = newyork_airbnb[newyork_airbnb['price_float']<=s]
newyork_airbnb_1
# Out:
#         Unnamed: 0          id  ...  day_scraped price_float
# 0                0  32239035.0  ...            7       170.0
# 1                1  14389040.0  ...            7       200.0
# 2                2  14378713.0  ...            7        38.0
# 3                3  14381523.0  ...            7       229.0
# 4                4  14382631.0  ...            7       147.0
# ...            ...         ...  ...          ...         ...
# 592514     2438321  35291681.0  ...            3        60.0
# 592515     2438322  35292625.0  ...            3        86.0
# 592516     2438323  35297530.0  ...            3       160.0
# 592517     2438324  35301609.0  ...            3        89.0
# 592518     2438325  35303893.0  ...            3       249.0
#
# [588157 rows x 17 columns]

# %%
newyork_airbnb_1.dropna()
# Out:
#         Unnamed: 0          id  ...  day_scraped price_float
# 1                1  14389040.0  ...            7       200.0
# 2                2  14378713.0  ...            7        38.0
# 3                3  14381523.0  ...            7       229.0
# 4                4  14382631.0  ...            7       147.0
# 5                5  14383283.0  ...            7        35.0
# ...            ...         ...  ...          ...         ...
# 592332     2438139  35224560.0  ...            3        55.0
# 592381     2438188  35235379.0  ...            3        36.0
# 592388     2438195  35238264.0  ...            3       100.0
# 592424     2438231  35257450.0  ...            3       350.0
# 592486     2438293  35279737.0  ...            3        60.0
#
# [459241 rows x 17 columns]

# %%
newyork_airbnb_1['last_review'] = pd.to_datetime(newyork_airbnb_1['last_review'])

# %%
newyork_airbnb_1.sort_values('last_review', inplace=True)

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=newyork_airbnb_1, color='tab:red')

# %%
newyork_airbnb_1['date'] = newyork_airbnb_1['last_review']

# %%
newyork_airbnb_1.set_index("date", inplace=True)

# %%
newyork_airbnb_2019 = newyork_airbnb_1[newyork_airbnb_1['last_review']>=pd.datetime(2019,1,1)]

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=newyork_airbnb_2019, color='tab:red')

# %%
newyork_airbnb_2019_day= newyork_airbnb_2019.resample('D').mean()
newyork_airbnb_2019_day = newyork_airbnb_2019_day.round(3)

# %%
newyork_airbnb_2019_day['ma10'] = newyork_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
newyork_airbnb_2019_day['ma20'] = newyork_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)

# %%
newyork_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
paris_airbnb['price_float'] = paris_airbnb['price'].str.replace(',', '').astype(float)

# %%
mean = paris_airbnb['price_float'].mean()
std = paris_airbnb['price_float'].std()
mean
# Out:
# 117.30541315515562

# %%
s = mean+3*std
s
# Out:
# 714.7627072819369

# %%
paris_airbnb_1 = paris_airbnb[paris_airbnb['price_float']<=s]
paris_airbnb_1
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0      2577  ...           12       125.0
# 1                1      3109  ...           12        75.0
# 2                2      5396  ...           12       115.0
# 3                3      7397  ...           12       115.0
# 4                4      8522  ...           12        90.0
# ...            ...       ...  ...          ...         ...
# 744570      810492  38668522  ...           17       100.0
# 744571      810493  38669728  ...           18        80.0
# 744572      810494  38670098  ...           17       150.0
# 744573      810495  38672395  ...           17        90.0
# 744574      810496  38672993  ...           18        30.0
#
# [736371 rows x 17 columns]

# %%
paris_airbnb_1.dropna()
# Out:
#         Unnamed: 0        id  ...  day_scraped price_float
# 0                0      2577  ...           12       125.0
# 1                1      3109  ...           12        75.0
# 2                2      5396  ...           12       115.0
# 3                3      7397  ...           12       115.0
# 4                4      8522  ...           12        90.0
# ...            ...       ...  ...          ...         ...
# 744483      810405  38618541  ...           18        55.0
# 744493      810415  38632664  ...           18       110.0
# 744528      810450  38644773  ...           18        60.0
# 744539      810461  38657739  ...           18       100.0
# 744566      810488  38668013  ...           18        80.0
#
# [572586 rows x 17 columns]

# %%
paris_airbnb_1['last_review'] = pd.to_datetime(paris_airbnb_1['last_review'])

# %%
paris_airbnb_1.sort_values('last_review', inplace=True)

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=paris_airbnb_1, color='tab:red')
plt.rcParams['agg.path.chunksize'] = 10000

# %%
london_airbnb_2019_day['ma10'] = london_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
london_airbnb_2019_day['ma20'] = london_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)
london_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
paris_airbnb_1['date'] = paris_airbnb_1['last_review']
paris_airbnb_1.set_index("date", inplace=True)

# %%
paris_airbnb_2019 = paris_airbnb_1[paris_airbnb_1['last_review']>=pd.datetime(2019,1,1)]
paris_airbnb_2019.dropna()
# Out:
#             Unnamed: 0        id  ...  day_scraped price_float
# date                              ...
# 2019-01-01      600904  30523757  ...           10       581.0
# 2019-01-01      543039  30559871  ...            7       180.0
# 2019-01-01      289438  22407484  ...            5        90.0
# 2019-01-01      294129  25158529  ...            5       160.0
# 2019-01-01      113382  30232127  ...           13       203.0
# ...                ...       ...  ...          ...         ...
# 2019-12-18      244267  39011489  ...           19        61.0
# 2019-12-18      244152  38951158  ...           19        91.0
# 2019-12-18      239070  36536579  ...           19        78.0
# 2019-12-18      228554  30649781  ...           19        60.0
# 2019-12-19      241160  37309832  ...           20        38.0
#
# [328590 rows x 17 columns]

# %%
plt.figure(figsize=(16,10), dpi= 80)
plt.plot('last_review', 'price_float', data=paris_airbnb_2019, color='tab:red')

# %%
paris_airbnb_2019_day= paris_airbnb_2019.resample('D').mean()
paris_airbnb_2019_day = paris_airbnb_2019_day.round(3)
paris_airbnb_2019_day
paris_airbnb_2019_day.dropna()
# Out:
#             Unnamed: 0            id  ...  day_scraped  price_float
# date                                  ...
# 2019-01-01  286576.926  1.874535e+07  ...       10.234      114.100
# 2019-01-02  283541.742  1.771014e+07  ...       10.157      120.542
# 2019-01-03  285163.869  1.759034e+07  ...       10.130      116.784
# 2019-01-04  266263.114  1.693995e+07  ...       10.166      129.020
# 2019-01-05  270291.708  1.677888e+07  ...       10.139      132.433
# ...                ...           ...  ...          ...          ...
# 2019-12-14  235174.333  3.418218e+07  ...       19.083       75.833
# 2019-12-15  245986.000  3.970990e+07  ...       19.000      117.000
# 2019-12-16  243140.000  3.833317e+07  ...       19.500      184.500
# 2019-12-18  239010.750  3.628725e+07  ...       19.000       72.500
# 2019-12-19  241160.000  3.730983e+07  ...       20.000       38.000
#
# [352 rows x 10 columns]

# %%
paris_airbnb_2019_day['ma10'] = paris_airbnb_2019_day['price_float'].rolling(10).mean().shift(-9)
paris_airbnb_2019_day['ma20'] = paris_airbnb_2019_day['price_float'].rolling(20).mean().shift(-19)
paris_airbnb_2019_day.plot( y=["ma10",'ma20'], style='-',figsize=(16,10))
plt.show()

# %%
# %%sh
# pip3 freeze | grep -E 'ipython|jupyter'
# Out:
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==5.2.0
# jupyter-core==4.6.3

# %%
# %%sh
# cat <<EOF > requirements_demo.txt
# h3==3.1.0
# pandas>=0.23
# geojson==2.4.1
# folium==0.2.1
# seaborn==0.9.0
# area==1.1.1
# statsmodels==0.9.0
# EOF

# %%
# %%sh
# pip3 install -U --quiet -r requirements_demo.txt

# %%
# %%sh
# pip3 freeze | grep -E 'h3|pandas|geojson|folium|seaborn|area|statsmodels'
# Out:
# area==1.1.1
# folium==0.2.1
# geojson==2.4.1
# h3==3.1.0
# pandas==1.0.3
# pandas-datareader==0.8.1
# pandas-gbq==0.11.0
# pandas-profiling==1.4.1
# seaborn==0.9.0
# sklearn-pandas==1.8.0
# statsmodels==0.9.0

# %%
# %%sh
# pwd
# mkdir datasets_demo
# Out:
# /content
# mkdir: cannot create directory ‘datasets_demo’: File exists

# %%
from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
from h3 import h3

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np

import statistics

from geojson.feature import *
from area import area

import copy

# %%
from folium import Map, Marker, GeoJson
from folium.plugins import MarkerCluster
import branca.colormap as cm
from branca.colormap import linear
import folium

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.display import Image, display
from IPython.utils.text import columnize
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
max_res = 10
list_hex_edge_km = []
list_hex_edge_m = []
list_hex_perimeter_km = []
list_hex_perimeter_m = []
list_hex_area_sqkm = []
list_hex_area_sqm = []

for i in range(0,max_res + 1):
    ekm = h3.edge_length(resolution=i, unit='km')
    em = h3.edge_length(resolution=i, unit='m')
    list_hex_edge_km.append(round(ekm,3))
    list_hex_edge_m.append(round(em,3))
    list_hex_perimeter_km.append(round(6 * ekm,3))
    list_hex_perimeter_m.append(round(6 * em,3))
    
    akm = h3.hex_area(resolution=i, unit='km^2')
    am = h3.hex_area(resolution=i, unit='m^2')
    list_hex_area_sqkm.append(round(akm,3))
    list_hex_area_sqm.append(round(am,3))

df_meta = pd.DataFrame({"edge_length_km" : list_hex_edge_km,
                        "perimeter_km" : list_hex_perimeter_km,
                        "area_sqkm": list_hex_area_sqkm,
                        "edge_length_m" : list_hex_edge_m,
                        "perimeter_m" : list_hex_perimeter_m,
                        "area_sqm" : list_hex_area_sqm
                       })
                      
df_meta[["edge_length_km","perimeter_km","area_sqkm", "edge_length_m", "perimeter_m" ,"area_sqm"]]
# Out:
#     edge_length_km  perimeter_km  ...  perimeter_m      area_sqm
# 0         1107.713      6646.276  ...  6646275.546  4.250550e+12
# 1          418.676      2512.056  ...  2512056.033  6.072210e+11
# 2          158.245       949.468  ...   949467.935  8.674585e+10
# 3           59.811       358.865  ...   358865.148  1.239226e+10
# 4           22.606       135.638  ...   135638.276  1.770324e+09
# 5            8.544        51.266  ...    51266.450  2.529034e+08
# 6            3.229        19.377  ...    19376.897  3.612905e+07
# 7            1.221         7.324  ...     7323.779  5.161293e+06
# 8            0.461         2.768  ...     2768.128  7.373276e+05
# 9            0.174         1.046  ...     1046.254  1.053325e+05
# 10           0.066         0.395  ...      395.447  1.504750e+04
#
# [11 rows x 6 columns]

# %%
lat_centr_point = 51
lon_centr_point = 0
list_hex_res = []
list_hex_res_geom = []
list_res = range(0,max_res+1)

for resolution in range(0,max_res + 1):
    #index the point in the H3 hexagon of given index resolution
    h = h3.geo_to_h3(lat=lat_centr_point,lng=lon_centr_point, res=resolution)
    list_hex_res.append(h)
    #get the geometry of the hexagon and convert to geojson
    h_geom = { "type" : "Polygon",
               "coordinates": 
                    [h3.h3_to_geo_boundary(h3_address=h,geo_json=True)]
              }
    list_hex_res_geom.append(h_geom)

    
df_resolution_example = pd.DataFrame({"res" : list_res,
                                      "hex_id" : list_hex_res,
                                      "geometry": list_hex_res_geom 
                                     })
df_resolution_example["hex_id_binary"] = df_resolution_example["hex_id"].apply(lambda x: bin(int(x,16))[2:])

pd.set_option('display.max_colwidth',63)
df_resolution_example
# Out:
#     res  ...                                                 hex_id_binary
# 0     0  ...  100000000001100111111111111111111111111111111111111111111111
# 1     1  ...  100000010001100101111111111111111111111111111111111111111111
# 2     2  ...  100000100001100101001111111111111111111111111111111111111111
# 3     3  ...  100000110001100101001010111111111111111111111111111111111111
# 4     4  ...  100001000001100101001010000111111111111111111111111111111111
# 5     5  ...  100001010001100101001010000000111111111111111111111111111111
# 6     6  ...  100001100001100101001010000110001111111111111111111111111111
# 7     7  ...  100001110001100101001010000000110010111111111111111111111111
# 8     8  ...  100010000001100101001010000000110010010111111111111111111111
# 9     9  ...  100010010001100101001010000000110010010110111111111111111111
# 10   10  ...  100010100001100101001010000000110010010110011111111111111111
#
# [11 rows x 4 columns]

# %%
def counts_by_hexagon(df, resolution):
    
    '''Use h3.geo_to_h3 to index each data point into the spatial index of the specified resolution.
      Use h3.h3_to_geo_boundary to obtain the geometries of these hexagons'''

    df = df[["latitude","longitude"]]
    
    df["hex_id"] = df.apply(lambda row: h3.geo_to_h3(row["latitude"], row["longitude"], resolution), axis = 1)
    
    df_aggreg = df.groupby(by = "hex_id").size().reset_index()
    df_aggreg.columns = ["hex_id", "value"]
    
    df_aggreg["geometry"] =  df_aggreg.hex_id.apply(lambda x: 
                                                           {    "type" : "Polygon",
                                                                 "coordinates": 
                                                                [h3.h3_to_geo_boundary(h3_address=x,geo_json=True)]
                                                            }
                                                        )
    
    return df_aggreg

# %%
df_aggreg = counts_by_hexagon(df = london_airbnb_2019, resolution = 9)
print(df_aggreg.shape)
df_aggreg.sort_values(by = "value", ascending = False, inplace = True)
df_aggreg.head(15)
# Out:
# (7585, 3)
#                hex_id  ...                                                        geometry
# 2115  89194ad3467ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.07168365203182248,...
# 1158  89194ad1643ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.1667463110046583, ...
# 5776  89195da4b53ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.18582530880064496,...
# 1181  89194ad16b3ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.14070379998781846,...
# 5696  89195da4987ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.13206166954870469,...
# 5795  89195da4bcfffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.18120603403696123,...
# 2116  89194ad346bffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.07925626822640197,...
# 3230  89194ada5c7ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.18817795203966625,...
# 5872  89195da4d6fffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.14094197367762717,...
# 3232  89194ada5cfffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.19279595009015793,...
# 5724  89195da4a27ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.1887888132565081, ...
# 2119  89194ad3477ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.07002344099396396,...
# 5889  89195da4dbbffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.12211237950469922,...
# 5793  89195da4bc7ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.17658690727449766,...
# 1928  89194ad3083ffff  ...  {'type': 'Polygon', 'coordinates': [[[-0.07038796165699068,...
#
# [15 rows x 3 columns]
